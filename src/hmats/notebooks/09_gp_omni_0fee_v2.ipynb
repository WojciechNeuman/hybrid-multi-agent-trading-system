# %% [markdown]
# # 09 — Genetic Programming v2: DEAP · M1Y WFO · 2-Week Step · Long+Short · 1h BTC · Boolean Gates
#
# ## v2 fixes vs v1
#
# | Problem (v1) | Root cause | Fix (v2) |
# |---|---|---|
# | Trade count unchanged at 2,026 despite ±1.5 threshold | GP inflated tree coefficients (via Add/Mul/Div/ephemeral constants) to easily exceed ±1.5, bypassing the threshold entirely | **logic_only=True** — ban Add, Mul, Div and ephemeral constants; keep only Sub + boolean gates |
# | v1 zero-fee Sharpe still negative (-0.033) | With arithmetic ops, GP evolved oscillatory expressions like Sub(rsi_7,rsi_21)×large_constant that fire on every bar | **Boolean-gate pset** forces output into {-1, 0, 1} naturally; cannot inflate coefficients |
# | Threshold gating bypassed by scaling | Scalar multiplication made any threshold trivially clearable | **No ephemeral constants** — trees can only combine feature relationships, not scale them |
#
# **Key insight:** Removing arithmetic scaling eliminates the coefficient-inflation attack.
# Sub(GT(a,b), GT(c,d)) gives exactly {-1, 0, 1} — the agent must find genuine market conditions,
# not just scale existing oscillators to clear an arbitrary threshold.
#
# **v1 zero-fee result:** -0.033 Sharpe / -2.9% return — not even a zero-fee edge.
# v2 targets structural sparsity: only fire when two boolean conditions are simultaneously true.
#
# | Design dimension | Choice |
# |---|---|
# | **Algorithm** | DEAP symbolic GP (tree-based) |
# | **Primitive set** | logic_only=True: Sub + GT, LT, And, Or, Not, IfPos only (NEW) |
# | **Arithmetic ops** | Banned: Add, Mul, Div — prevents coefficient-scaling attack |
# | **Ephemeral constants** | Removed — no arbitrary scaling |
# | **Feature diet** | 12 stationary oscillators (unchanged) |
# | **WFO scheme** | M1Y sliding · 8760h train · **336h step (14 days)** · ~182 folds |
# | **Flat threshold** | ±0.5 — output ≥ 0.5 → Long, ≤ -0.5 → Short, else Flat |
# | **Step rationale** | 2-week step vs 1-month: crypto regimes shift fast; doubling fold density gives MetaSupervisor 2× regime pivot points; GP rules only need to survive 14 days OOS instead of 30 |
# | **AFML Ch. 2** | Bounded oscillators only — no raw price levels |
# | **AFML Ch. 7** | Last 12 bars purged from fitness evaluation |
# | **AFML Ch. 14** | Parsimony penalty: Fitness = Sharpe − α × n_nodes (α=0.002) |

# %%
import calendar
import json
import time
import warnings
from pathlib import Path

import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from hmats.agents.gp_agent import GP_FEATURES, GPTradingAgent
from hmats.viz.plots import plot_equity_drawdown, save_fig

warnings.filterwarnings('ignore')
pd.set_option('display.float_format', '{:.4f}'.format)

try:    plt.style.use('seaborn-v0_8-whitegrid')
except: plt.style.use('seaborn-whitegrid')
mpl.rcParams.update({
    'font.family': 'serif', 'font.serif': ['DejaVu Serif'],
    'axes.spines.top': False, 'axes.spines.right': False,
    'axes.labelsize': 10, 'axes.titlesize': 11,
    'xtick.labelsize': 9, 'ytick.labelsize': 9,
    'legend.fontsize': 9, 'legend.framealpha': 0.85,
    'figure.dpi': 120, 'savefig.dpi': 150, 'savefig.bbox': 'tight',
})
ACCENT='#F7931A'; BLUE='#2962FF'; GREY='#9E9E9E'
RED='#EF5350'; GREEN='#26A69A'; PURPLE='#7B1FA2'

# ── WFO / OOS config ─────────────────────────────────────────────────────────
OOS_START      = pd.Timestamp('2024-01-01')
TRAIN_WINDOW_H = 8760   # 1 year — full macro cycle needed for oscillator calibration
STEP_SIZE      = 336    # 14 days (2-week step) — faster regime adaptation vs 1-month (720h)
EMBARGO        = 12     # AFML Ch.7: purge last 12 bars from train — prevents SL/TP leakage

# ── GP v2 hyperparameters ─────────────────────────────────────────────────────
POP_SIZE        = 400          # kept from v1
GENERATIONS     = 40           # kept from v1
PARSIMONY       = 0.002        # kept from v1
CX_PROB         = 0.40         # kept from v1
MUT_PROB        = 0.40         # kept from v1
FLAT_THRESHOLD  = 0.5          # v2: tighter threshold — boolean ops output {-1,0,1} exactly
LOGIC_ONLY      = True         # v2: ban Add/Mul/Div/constants — boolean-gate pset only (NEW)

# ── Fee model ────────────────────────────────────────────────────────────────
TAKER_FEE = 0.0005
FUNDING_H = 0.0000077

print(f'GP features     : {len(GP_FEATURES)}')
print(f'OOS start       : {OOS_START.date()}')
print(f'Step size       : {STEP_SIZE}h  ({STEP_SIZE/24:.0f} days — 2-week retraining cadence)')
print(f'Train window    : {TRAIN_WINDOW_H}h  ({TRAIN_WINDOW_H/24/365:.1f} year lookback)')
print(f'Embargo         : {EMBARGO}h  (AFML Ch.7 purge)')
print(f'Population      : {POP_SIZE}  Generations: {GENERATIONS}')
print(f'Parsimony \u03b1    : {PARSIMONY}  (down from 0.010)')
print(f'cx_prob / mut   : {CX_PROB} / {MUT_PROB}  (was 0.70 / 0.25)')
print(f'Flat threshold  : \u00b1{FLAT_THRESHOLD}  (tighter — boolean ops produce {{-1,0,1}})')
print(f'Logic only      : {LOGIC_ONLY}  (NEW \u2014 bans Add/Mul/Div/constants)')
print('Imports OK')
# Out:
# GP features     : 12
# OOS start       : 2024-01-01
# Step size       : 336h  (14 days — 2-week retraining cadence)
# Train window    : 8760h  (1.0 year lookback)
# Embargo         : 12h  (AFML Ch.7 purge)
# Population      : 400  Generations: 40
# Parsimony α    : 0.002  (down from 0.010)
# cx_prob / mut   : 0.4 / 0.4  (was 0.70 / 0.25)
# Flat threshold  : ±0.5  (tighter — boolean ops produce {-1,0,1})
# Logic only      : True  (NEW — bans Add/Mul/Div/constants)
# Imports OK

# %%
def _find_repo_root() -> Path:
    p = Path.cwd()
    while p != p.parent:
        if (p / 'pyproject.toml').exists(): return p
        p = p.parent
    raise RuntimeError('repo root not found')

REPO_DIR = _find_repo_root()
FEAT_DIR = REPO_DIR / 'data' / 'features'
ARTS_DIR = REPO_DIR / 'artifacts' / '09_gp_omni_0fee_v2'
ARTS_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts \u2192 {ARTS_DIR}')
# Out:
# Artifacts → /Users/wojciech.neuman/Documents/hybrid-multi-agent-trading-system/artifacts/09_gp_omni_0fee_v2

# %%
# GP uses only V1 features — all 12 GP_FEATURES are in the V1 parquet.
print('Loading V1 features...')
v1 = pd.read_parquet(FEAT_DIR / 'BTCUSDT_1h_features.parquet')
v1.index = v1.index.tz_localize(None) if v1.index.tz else v1.index

_raw = pd.read_parquet(REPO_DIR / 'data' / 'raw' / 'BTCUSDT_1h.parquet')
_raw.index = _raw.index.tz_convert(None)

merged = v1.copy()
merged['high'] = _raw['high'].reindex(merged.index)
merged['low']  = _raw['low'].reindex(merged.index)

present = [f for f in GP_FEATURES if f in merged.columns]
missing = [f for f in GP_FEATURES if f not in merged.columns]
print(f'GP features present: {len(present)} / {len(GP_FEATURES)}')
if missing: print(f'  Missing: {missing}')

oos_mask = merged.index >= OOS_START
oos_df   = merged[oos_mask].copy()
print(f'Total bars: {len(merged):,}  |  OOS bars: {len(oos_df):,}')

# AFML Ch.2 sanity check
price_cols = [f for f in GP_FEATURES if f in ('close', 'open', 'high', 'low', 'volume')]
assert not price_cols, f'AFML Ch.2 violation: raw price columns in GP diet: {price_cols}'
print('\nAFML Ch. 2 check PASSED \u2014 no raw price levels in feature diet')
print('\nGP feature diet:')
for f in GP_FEATURES:
    tag = '\u2713' if f in merged.columns else '\u2717 MISSING'
    print(f'  {tag}  {f}')
# Out:
# Loading V1 features...
# GP features present: 12 / 12
# Total bars: 74,366  |  OOS bars: 20,785
#
# AFML Ch. 2 check PASSED — no raw price levels in feature diet
#
# GP feature diet:
#   ✓  rsi_7
#   ✓  rsi_21
#   ✓  stoch_k_21
#   ✓  bb_position_50
#   ✓  bb_squeeze_20
#   ✓  mfi_14
#   ✓  williams_r
#   ✓  cmf_20
#   ✓  macd_hist_12_26
#   ✓  hl_position_24h
#   ✓  obv_z_72
#   ✓  vol_z_24h

# %%
# ── PHASE 1: GP WFO signal generation ────────────────────────────────────────
print('='*60)
print('PHASE 1 \u2014 M1Y WFO: Genetic Programming v2 signal generation')
print('='*60)
print(f'  v2 fixes active:')
print(f'    flat_threshold = \u00b1{FLAT_THRESHOLD}  (NEW \u2014 prevents binary-toggle degeneracy)')
print(f'    parsimony \u03b1  = {PARSIMONY}  (down from 0.010 \u2014 allows richer trees)')
print(f'    cx_prob       = {CX_PROB}  (down from 0.70)')
print(f'    mut_prob      = {MUT_PROB}  (up from 0.25 \u2014 more search diversity)')
print(f'    pop_size      = {POP_SIZE}  (up from 300)')
print(f'    generations   = {GENERATIONS}  (up from 30)')

agent = GPTradingAgent(
    features=[f for f in GP_FEATURES if f in merged.columns],
    population_size=POP_SIZE,
    generations=GENERATIONS,
    parsimony_coefficient=PARSIMONY,
    train_window_h=TRAIN_WINDOW_H,
    step_size=STEP_SIZE,
    cx_prob=CX_PROB,
    mut_prob=MUT_PROB,
    flat_threshold=FLAT_THRESHOLD,
    logic_only=LOGIC_ONLY,
    agent_id='gp_v2',
)

t0 = time.time()
gp_signals = agent.generate_signals(merged, oos_start=OOS_START, verbose=True)
print(f'Done in {(time.time()-t0)/60:.1f} min')

sig_path = ARTS_DIR / 'gp_oos_signals.parquet'
gp_signals.to_frame().to_parquet(sig_path)
print(f'Signals saved \u2192 {sig_path}')

vc = gp_signals.value_counts().sort_index()
for k, v in vc.items():
    name = {-1: 'Short', 0: 'Flat', 1: 'Long'}.get(k, str(k))
    print(f'  {name:5}: {v:5,}  ({v/len(gp_signals)*100:.1f}%)')
# Out:
# ============================================================
# PHASE 1 — M1Y WFO: Genetic Programming v2 signal generation
# ============================================================
#   v2 fixes active:
#     flat_threshold = ±0.5  (NEW — prevents binary-toggle degeneracy)
#     parsimony α  = 0.002  (down from 0.010 — allows richer trees)
#     cx_prob       = 0.4  (down from 0.70)
#     mut_prob      = 0.4  (up from 0.25 — more search diversity)
#     pop_size      = 400  (up from 300)
#     generations   = 40  (up from 30)
#   [gp_v2] fold   1  fitness=+32.7749  nodes= 10  height=3  gen_max=+32.7749
#   [gp_v2] fold   2  fitness=+34.4457  nodes= 20  height=4  gen_max=+34.4457
#   [gp_v2] fold   3  fitness=+32.9207  nodes= 17  height=5  gen_max=+32.8819
#   [gp_v2] fold   4  fitness=+34.6684  nodes= 47  height=8  gen_max=+34.5467
#   [gp_v2] fold   5  fitness=+35.0341  nodes= 42  height=8  gen_max=+34.9376
#   [gp_v2] fold   6  fitness=+35.2354  nodes= 48  height=8  gen_max=+35.0156
#   [gp_v2] fold   7  fitness=+35.7797  nodes= 19  height=6  gen_max=+35.7797
#   [gp_v2] fold   8  fitness=+33.1384  nodes=  7  height=3  gen_max=+33.1384
#   [gp_v2] fold   9  fitness=+32.9884  nodes= 27  height=6  gen_max=+32.9884
#   [gp_v2] fold  10  fitness=+31.9223  nodes=  6  height=3  gen_max=+31.9223
#   [gp_v2] fold  11  fitness=+32.6130  nodes= 58  height=8  gen_max=+32.6130
#   [gp_v2] fold  12  fitness=+31.5202  nodes=  5  height=2  gen_max=+31.5182
#   [gp_v2] fold  13  fitness=+31.3279  nodes=  7  height=2  gen_max=+31.2887
#   [gp_v2] fold  14  fitness=+32.6074  nodes= 25  height=7  gen_max=+32.6034
#   [gp_v2] fold  15  fitness=+31.7258  nodes= 50  height=8  gen_max=+31.7258
#   [gp_v2] fold  16  fitness=+33.2428  nodes= 19  height=6  gen_max=+33.2428
#   [gp_v2] fold  17  fitness=+32.3526  nodes= 30  height=8  gen_max=+32.3526
#   [gp_v2] fold  18  fitness=+31.8079  nodes=  9  height=3  gen_max=+31.8079
#   [gp_v2] fold  19  fitness=+33.6830  nodes= 49  height=7  gen_max=+33.6830
#   [gp_v2] fold  20  fitness=+31.6479  nodes=  5  height=2  gen_max=+31.6479
#   [gp_v2] fold  21  fitness=+31.8362  nodes=  5  height=2  gen_max=+31.8362
#   [gp_v2] fold  22  fitness=+31.7538  nodes=  5  height=2  gen_max=+31.7538
#   [gp_v2] fold  23  fitness=+31.6252  nodes=  5  height=2  gen_max=+31.6252
#   [gp_v2] fold  24  fitness=+31.8182  nodes= 35  height=8  gen_max=+31.8182
#   [gp_v2] fold  25  fitness=+31.9589  nodes=  5  height=2  gen_max=+31.9589
#   [gp_v2] fold  26  fitness=+33.6604  nodes= 26  height=8  gen_max=+33.5483
#   [gp_v2] fold  27  fitness=+32.7899  nodes= 32  height=6  gen_max=+32.7899
#   [gp_v2] fold  28  fitness=+32.7007  nodes= 36  height=8  gen_max=+32.7007
#   [gp_v2] fold  29  fitness=+31.9689  nodes=  7  height=3  gen_max=+31.9689
#   [gp_v2] fold  30  fitness=+31.9448  nodes= 11  height=4  gen_max=+31.8772
#   [gp_v2] fold  31  fitness=+33.2023  nodes= 19  height=8  gen_max=+33.2023
#   [gp_v2] fold  32  fitness=+34.3010  nodes= 48  height=7  gen_max=+34.3010
#   [gp_v2] fold  33  fitness=+34.1095  nodes= 46  height=8  gen_max=+34.1095
#   [gp_v2] fold  34  fitness=+34.6685  nodes= 52  height=7  gen_max=+34.6685
#   [gp_v2] fold  35  fitness=+34.6821  nodes= 37  height=6  gen_max=+34.6821
#   [gp_v2] fold  36  fitness=+32.4204  nodes= 16  height=4  gen_max=+32.4204
#   [gp_v2] fold  37  fitness=+33.6212  nodes= 29  height=7  gen_max=+33.6212
#   [gp_v2] fold  38  fitness=+33.2236  nodes= 21  height=5  gen_max=+33.2236
#   [gp_v2] fold  39  fitness=+33.2933  nodes= 45  height=8  gen_max=+33.2933
#   [gp_v2] fold  40  fitness=+33.3766  nodes= 25  height=7  gen_max=+33.3766
#   [gp_v2] fold  41  fitness=+33.6169  nodes= 53  height=8  gen_max=+33.6169
#   [gp_v2] fold  42  fitness=+30.2263  nodes= 37  height=8  gen_max=+30.2263
#   [gp_v2] fold  43  fitness=+32.9680  nodes= 19  height=5  gen_max=+32.9680
#   [gp_v2] fold  44  fitness=+31.4175  nodes= 34  height=8  gen_max=+31.4175
#   [gp_v2] fold  45  fitness=+27.2344  nodes= 51  height=8  gen_max=+27.2344
#   [gp_v2] fold  46  fitness=+32.1715  nodes= 21  height=6  gen_max=+32.1715
#   [gp_v2] fold  47  fitness=+31.3109  nodes= 22  height=6  gen_max=+31.3109
#   [gp_v2] fold  48  fitness=+31.5493  nodes= 21  height=5  gen_max=+31.5493
#   [gp_v2] fold  49  fitness=+32.0236  nodes= 60  height=8  gen_max=+32.0236
#   [gp_v2] fold  50  fitness=+22.8742  nodes= 36  height=8  gen_max=+22.8742
#   [gp_v2] fold  51  fitness=+31.3983  nodes= 31  height=5  gen_max=+31.3882
#   [gp_v2] fold  52  fitness=+32.2475  nodes= 20  height=7  gen_max=+32.2287
#   [gp_v2] fold  53  fitness=+33.2369  nodes= 26  height=6  gen_max=+33.2369
#   [gp_v2] fold  54  fitness=+32.7781  nodes= 16  height=4  gen_max=+32.7778
#   [gp_v2] fold  55  fitness=+32.7108  nodes= 26  height=7  gen_max=+32.7108
#   [gp_v2] fold  56  fitness=+33.8015  nodes= 35  height=8  gen_max=+33.8015
#   [gp_v2] fold  57  fitness=+33.9968  nodes= 31  height=7  gen_max=+33.8965
#   [gp_v2] fold  58  fitness=+31.0316  nodes= 26  height=8  gen_max=+31.0316
#   [gp_v2] fold  59  fitness=+33.2732  nodes= 28  height=6  gen_max=+33.2732
#   [gp_v2] fold  60  fitness=+33.6271  nodes= 37  height=7  gen_max=+33.6271
#   [gp_v2] fold  61  fitness=+34.3719  nodes= 25  height=6  gen_max=+34.3719
#   [gp_v2] fold  62  fitness=+35.2457  nodes= 10  height=3  gen_max=+34.7532
#   [gp_v2] fold  63  fitness=+28.6636  nodes=  6  height=2  gen_max=+28.6636
#   [gp_v2] fold  64  fitness=+36.8557  nodes= 23  height=8  gen_max=+36.8557
#   [gp_v2] fold  65  fitness=+37.3923  nodes= 36  height=7  gen_max=+37.3923
#   [gp_v2] fold  66  fitness=+35.9965  nodes= 21  height=5  gen_max=+35.9965
#   [gp_v2] fold  67  fitness=+38.2484  nodes= 17  height=5  gen_max=+38.2484
#   [gp_v2] fold  68  fitness=+37.8822  nodes= 39  height=8  gen_max=+37.8822
#   [gp_v2] fold  69  fitness=+39.6772  nodes= 42  height=8  gen_max=+39.6772
#   [gp_v2] fold  70  fitness=+37.2090  nodes=  7  height=3  gen_max=+37.2090
#   [gp_v2] fold  71  fitness=+39.2444  nodes= 19  height=8  gen_max=+39.2444
#   [gp_v2] fold  72  fitness=+39.6839  nodes= 36  height=8  gen_max=+39.6817
#   [gp_v2] fold  73  fitness=+39.5028  nodes= 12  height=4  gen_max=+39.5028
#   [gp_v2] fold  74  fitness=+42.2116  nodes= 29  height=7  gen_max=+42.2116
#   [gp_v2] fold  75  fitness=+39.9436  nodes= 24  height=5  gen_max=+39.9436
#   [gp_v2] fold  76  fitness=+43.6893  nodes= 26  height=8  gen_max=+43.6893
#   [gp_v2] fold  77  fitness=+41.0949  nodes= 39  height=8  gen_max=+41.0909
#   [gp_v2] fold  78  fitness=+41.3269  nodes= 26  height=6  gen_max=+41.1469
#   [gp_v2] fold  79  fitness=+41.2965  nodes= 42  height=6  gen_max=+41.2965
#   [gp_v2] fold  80  fitness=+40.5750  nodes= 36  height=8  gen_max=+40.5750
#   [gp_v2] fold  81  fitness=+42.7275  nodes= 12  height=4  gen_max=+42.7275
#   [gp_v2] fold  82  fitness=+40.3231  nodes= 42  height=8  gen_max=+40.3231
#   [gp_v2] fold  83  fitness=+40.0926  nodes= 16  height=3  gen_max=+40.0926
#   [gp_v2] fold  84  fitness=+42.0792  nodes= 46  height=8  gen_max=+42.0792
#   [gp_v2] fold  85  fitness=+41.0694  nodes= 24  height=8  gen_max=+41.0694
#   [gp_v2] fold  86  fitness=+42.4725  nodes= 59  height=8  gen_max=+42.4725
#   [gp_v2] fold  87  fitness=+41.0506  nodes= 19  height=5  gen_max=+41.0506
#   [gp_v2] fold  88  fitness=+40.1314  nodes= 12  height=3  gen_max=+40.1314
#   [gp_v2] fold  89  fitness=+42.0064  nodes= 17  height=7  gen_max=+42.0064
#   [gp_v2] fold  90  fitness=+40.7825  nodes= 48  height=7  gen_max=+40.7825
#   [gp_v2] fold  91  fitness=+40.9197  nodes= 69  height=8  gen_max=+40.9197
#   [gp_v2] fold  92  fitness=+42.7179  nodes= 49  height=8  gen_max=+42.7179
#   [gp_v2] fold  93  fitness=+41.3628  nodes= 20  height=5  gen_max=+41.3628
#   [gp_v2] fold  94  fitness=+40.5219  nodes= 20  height=5  gen_max=+40.5219
#   [gp_v2] fold  95  fitness=+42.9796  nodes= 17  height=6  gen_max=+42.9796
#   [gp_v2] fold  96  fitness=+39.7162  nodes= 33  height=8  gen_max=+39.6745
#   [gp_v2] fold  97  fitness=+39.9611  nodes= 24  height=4  gen_max=+39.9611
#   [gp_v2] fold  98  fitness=+39.5647  nodes= 28  height=5  gen_max=+39.5647
#   [gp_v2] fold  99  fitness=+40.1093  nodes= 40  height=7  gen_max=+40.1093
#   [gp_v2] fold 100  fitness=+38.4973  nodes= 38  height=8  gen_max=+38.4973
#   [gp_v2] fold 101  fitness=+40.1864  nodes= 49  height=8  gen_max=+40.1864
#   [gp_v2] fold 102  fitness=+39.3894  nodes= 17  height=4  gen_max=+39.3894
#   [gp_v2] fold 103  fitness=+39.8775  nodes= 30  height=8  gen_max=+39.8775
#   [gp_v2] fold 104  fitness=+39.7138  nodes= 36  height=7  gen_max=+39.7138
#   [gp_v2] fold 105  fitness=+39.1520  nodes= 26  height=6  gen_max=+39.1520
#   [gp_v2] fold 106  fitness=+37.7895  nodes= 50  height=8  gen_max=+37.7895
#   [gp_v2] fold 107  fitness=+37.5466  nodes= 38  height=7  gen_max=+37.3821
#   [gp_v2] fold 108  fitness=+36.9360  nodes= 15  height=4  gen_max=+36.9360
#   [gp_v2] fold 109  fitness=+38.1832  nodes= 48  height=8  gen_max=+38.0203
#   [gp_v2] fold 110  fitness=+37.2914  nodes= 74  height=8  gen_max=+37.2914
#   [gp_v2] fold 111  fitness=+37.6460  nodes= 17  height=5  gen_max=+37.6460
#   [gp_v2] fold 112  fitness=+37.3108  nodes= 13  height=5  gen_max=+37.3108
#   [gp_v2] fold 113  fitness=+36.4683  nodes= 34  height=7  gen_max=+36.4338
#   [gp_v2] fold 114  fitness=+35.2363  nodes= 17  height=4  gen_max=+35.2363
#   [gp_v2] fold 115  fitness=+35.6329  nodes= 67  height=8  gen_max=+35.6329
#   [gp_v2] fold 116  fitness=+36.2399  nodes= 38  height=6  gen_max=+36.2399
#   [gp_v2] fold 117  fitness=+35.1049  nodes= 32  height=7  gen_max=+35.1049
#   [gp_v2] fold 118  fitness=+34.9916  nodes= 70  height=8  gen_max=+34.9916
#   [gp_v2] fold 119  fitness=+34.4656  nodes= 67  height=7  gen_max=+34.4656
#   [gp_v2] fold 120  fitness=+34.2685  nodes= 34  height=8  gen_max=+34.2685
#   [gp_v2] fold 121  fitness=+35.4370  nodes= 37  height=6  gen_max=+35.4370
#   [gp_v2] fold 122  fitness=+33.7421  nodes= 41  height=8  gen_max=+33.7421
#   [gp_v2] fold 123  fitness=+34.8086  nodes= 33  height=7  gen_max=+34.8086
#   [gp_v2] fold 124  fitness=+34.4099  nodes= 48  height=7  gen_max=+34.4099
#   [gp_v2] fold 125  fitness=+33.3098  nodes= 46  height=8  gen_max=+33.2578
#   [gp_v2] fold 126  fitness=+31.8576  nodes= 37  height=6  gen_max=+31.8576
#   [gp_v2] fold 127  fitness=+32.4305  nodes= 11  height=4  gen_max=+32.4305
#   [gp_v2] fold 128  fitness=+31.1486  nodes= 34  height=8  gen_max=+31.1115
#   [gp_v2] fold 129  fitness=+32.3170  nodes= 42  height=8  gen_max=+32.3170
#   [gp_v2] fold 130  fitness=+32.9610  nodes= 61  height=8  gen_max=+32.9610
#   [gp_v2] fold 131  fitness=+34.0661  nodes= 37  height=8  gen_max=+34.0661
#   [gp_v2] fold 132  fitness=+33.5248  nodes= 53  height=7  gen_max=+33.5248
#   [gp_v2] fold 133  fitness=+33.3791  nodes= 41  height=8  gen_max=+33.3791
#   [gp_v2] fold 134  fitness=+33.5210  nodes= 32  height=7  gen_max=+33.3502
#   [gp_v2] fold 135  fitness=+34.3372  nodes= 15  height=5  gen_max=+34.3372
#   [gp_v2] fold 136  fitness=+36.3186  nodes= 27  height=5  gen_max=+36.3186
#   [gp_v2] fold 137  fitness=+35.6661  nodes= 43  height=8  gen_max=+35.6661
#   [gp_v2] fold 138  fitness=+35.2580  nodes= 40  height=8  gen_max=+35.2580
#   [gp_v2] fold 139  fitness=+35.2106  nodes= 31  height=7  gen_max=+35.2106
#   [gp_v2] fold 140  fitness=+37.3371  nodes= 32  height=8  gen_max=+37.3371
#   [gp_v2] fold 141  fitness=+36.1518  nodes= 30  height=7  gen_max=+36.1478
#   [gp_v2] fold 142  fitness=+35.7587  nodes= 17  height=4  gen_max=+35.7495
#   [gp_v2] fold 143  fitness=+37.6745  nodes= 54  height=6  gen_max=+37.6745
#   [gp_v2] fold 144  fitness=+36.8530  nodes= 22  height=8  gen_max=+36.8530
#   [gp_v2] fold 145  fitness=+36.0587  nodes=  9  height=3  gen_max=+36.0587
#   [gp_v2] fold 146  fitness=+38.2568  nodes= 25  height=6  gen_max=+37.4827
#   [gp_v2] fold 147  fitness=+37.7251  nodes= 63  height=7  gen_max=+37.7251
#   [gp_v2] fold 148  fitness=+36.3696  nodes= 22  height=4  gen_max=+36.3696
#   [gp_v2] fold 149  fitness=+35.9016  nodes=  9  height=3  gen_max=+35.9016
#   [gp_v2] fold 150  fitness=+38.0866  nodes= 16  height=3  gen_max=+38.0866
#   [gp_v2] fold 151  fitness=+37.6742  nodes= 21  height=7  gen_max=+37.6742
#   [gp_v2] fold 152  fitness=+41.5959  nodes= 40  height=8  gen_max=+41.5959
#   [gp_v2] fold 153  fitness=+39.2216  nodes= 16  height=5  gen_max=+39.2216
#   [gp_v2] fold 154  fitness=+39.6586  nodes= 22  height=6  gen_max=+39.6586
#   [gp_v2] fold 155  fitness=+39.2674  nodes= 41  height=8  gen_max=+39.2674
#   [gp_v2] fold 156  fitness=+38.4295  nodes= 26  height=5  gen_max=+38.4295
#   [gp_v2] fold 157  fitness=+39.8785  nodes= 64  height=8  gen_max=+39.8785
#   [gp_v2] fold 158  fitness=+40.1337  nodes= 29  height=8  gen_max=+40.1337
#   [gp_v2] fold 159  fitness=+38.5109  nodes=  7  height=2  gen_max=+38.5109
#   [gp_v2] fold 160  fitness=+41.3036  nodes= 16  height=4  gen_max=+41.3036
#   [gp_v2] fold 161  fitness=+38.2859  nodes= 19  height=6  gen_max=+38.2819
#   [gp_v2] fold 162  fitness=+42.4569  nodes= 61  height=8  gen_max=+42.4569
#   [gp_v2] fold 163  fitness=+38.3007  nodes= 13  height=4  gen_max=+37.9499
#   [gp_v2] fold 164  fitness=+39.4460  nodes= 26  height=5  gen_max=+39.4460
#   [gp_v2] fold 165  fitness=+40.1298  nodes= 63  height=8  gen_max=+40.1298
#   [gp_v2] fold 166  fitness=+39.9821  nodes= 52  height=8  gen_max=+39.9821
#   [gp_v2] fold 167  fitness=+41.9819  nodes= 17  height=4  gen_max=+41.9819
#   [gp_v2] fold 168  fitness=+38.3028  nodes= 26  height=6  gen_max=+38.3028
#   [gp_v2] fold 169  fitness=+39.1583  nodes= 26  height=5  gen_max=+39.1583
#   [gp_v2] fold 170  fitness=+40.6674  nodes= 33  height=8  gen_max=+40.3877
#   [gp_v2] fold 171  fitness=+38.9967  nodes= 13  height=4  gen_max=+38.9967
#   [gp_v2] fold 172  fitness=+40.2410  nodes= 53  height=8  gen_max=+40.2410
#   [gp_v2] fold 173  fitness=+40.8273  nodes= 24  height=8  gen_max=+40.8273
#   [gp_v2] fold 174  fitness=+40.5286  nodes= 22  height=7  gen_max=+40.5286
#   [gp_v2] fold 175  fitness=+40.6867  nodes= 50  height=8  gen_max=+40.6760
#   [gp_v2] fold 176  fitness=+38.3905  nodes= 50  height=8  gen_max=+38.3905
#   [gp_v2] fold 177  fitness=+38.7050  nodes=  7  height=2  gen_max=+38.7050
#   [gp_v2] fold 178  fitness=+40.0905  nodes= 23  height=6  gen_max=+40.0905
#   [gp_v2] fold 179  fitness=+42.3910  nodes= 15  height=4  gen_max=+42.3910
#   [gp_v2] fold 180  fitness=+38.1103  nodes= 10  height=3  gen_max=+38.1067
#   [gp_v2] fold 181  fitness=+39.5829  nodes= 17  height=5  gen_max=+39.5829
#   [gp_v2] fold 182  fitness=+39.9197  nodes= 23  height=8  gen_max=+39.9197
#   [gp_v2] fold 183  fitness=+38.1646  nodes=  7  height=2  gen_max=+38.1646
#   [gp_v2] fold 184  fitness=+40.1118  nodes= 31  height=8  gen_max=+40.1118
#   [gp_v2] fold 185  fitness=+40.2343  nodes= 36  height=8  gen_max=+40.2343
#   [gp_v2] fold 186  fitness=+39.6796  nodes= 32  height=7  gen_max=+39.6796
#   [gp_v2] fold 187  fitness=+39.2428  nodes= 31  height=7  gen_max=+39.2428
#   [gp_v2] fold 188  fitness=+38.8886  nodes= 19  height=5  gen_max=+38.8886
#   [gp_v2] fold 189  fitness=+38.8665  nodes= 30  height=7  gen_max=+38.8665
#   [gp_v2] fold 190  fitness=+40.8067  nodes= 49  height=8  gen_max=+40.8067
#   [gp_v2] fold 191  fitness=+38.8234  nodes= 26  height=7  gen_max=+38.8234
#   [gp_v2] fold 192  fitness=+42.5341  nodes= 32  height=7  gen_max=+42.5341
#   [gp_v2] fold 193  fitness=+39.8879  nodes= 29  height=6  gen_max=+39.8076
#   [gp_v2] fold 194  fitness=+39.7590  nodes= 28  height=7  gen_max=+39.5758
#   [gp_v2] fold 195  fitness=+39.9422  nodes= 39  height=8  gen_max=+39.9422
#   [gp_v2] fold 196  fitness=+38.9347  nodes= 20  height=5  gen_max=+38.9347
# [gp_v2] WFO done: 196 folds  OOS Long=7612  Short=6890  Flat=6283
# Done in 5.7 min
# Signals saved → /Users/wojciech.neuman/Documents/hybrid-multi-agent-trading-system/artifacts/09_gp_omni_0fee_v2/gp_oos_signals.parquet
#   Short: 6,890  (33.1%)
#   Flat : 6,283  (30.2%)
#   Long : 7,612  (36.6%)

# %%
# ── Evolved rule tree inspection ──────────────────────────────────────────────
print('='*60)
print('EVOLVED RULE TREES \u2014 Walk-Forward Windows')
print('='*60)
print(f'Logic-only pset (no Add/Mul/Div/constants) should produce boolean gate rules.')
print(f'Sub(GT(a,b), GT(c,d)) gives {{-1,0,1}} — no coefficient inflation possible.\n')

oos_folds = [fw for fw in agent.fold_winners if fw['oos_start'] >= OOS_START]

for fw in oos_folds:
    print(f"Fold {fw['fold']:>3}  OOS: {fw['oos_start'].date()} \u2192 {fw['oos_end'].date()}")
    print(f"  Fitness: {fw['fitness']:+.4f}  (Sharpe \u2212 {PARSIMONY} \u00d7 {fw['n_nodes']} nodes)")
    print(f"  Nodes: {fw['n_nodes']}  Height: {fw['height']}")
    print(f"  Rule: {fw['tree_str']}")
    print()

if not oos_folds:
    print('(No OOS folds found \u2014 run generate_signals first)')

if agent.fold_winners:
    all_nodes   = [fw['n_nodes']  for fw in agent.fold_winners]
    all_heights = [fw['height']   for fw in agent.fold_winners]
    all_fitness = [fw['fitness']  for fw in agent.fold_winners]
    all_rules   = [fw['tree_str'] for fw in agent.fold_winners]
    unique_rules = len(set(all_rules))
    print(f'\nAll-folds summary  ({len(agent.fold_winners)} folds):')
    print(f'  n_nodes  \u2014 mean: {np.mean(all_nodes):.1f}   range: [{min(all_nodes)}, {max(all_nodes)}]')
    print(f'  height   \u2014 mean: {np.mean(all_heights):.1f}  range: [{min(all_heights)}, {max(all_heights)}]')
    print(f'  fitness  \u2014 mean: {np.mean(all_fitness):+.4f}  best: {max(all_fitness):+.4f}')
    print(f'  unique rules: {unique_rules} / {len(agent.fold_winners)}  (v1 had persistent Sub(rsi_7,rsi_21) dominance)')
# Out:
# ============================================================
# EVOLVED RULE TREES — Walk-Forward Windows
# ============================================================
# Logic-only pset (no Add/Mul/Div/constants) should produce boolean gate rules.
# Sub(GT(a,b), GT(c,d)) gives {-1,0,1} — no coefficient inflation possible.
#
# Fold 135  OOS: 2024-01-09 → 2024-01-23
#   Fitness: +34.3372  (Sharpe − 0.002 × 15 nodes)
#   Nodes: 15  Height: 5
#   Rule: Sub(IfPos(LT(rsi_7, bb_squeeze_20), Not(GT(GT(mfi_14, rsi_7), bb_squeeze_20)), rsi_7), GT(rsi_21, rsi_7))
#
# Fold 136  OOS: 2024-01-23 → 2024-02-06
#   Fitness: +36.3186  (Sharpe − 0.002 × 27 nodes)
#   Nodes: 27  Height: 5
#   Rule: Sub(IfPos(Sub(rsi_7, Sub(mfi_14, rsi_7)), Sub(rsi_7, Sub(mfi_14, rsi_7)), Sub(GT(hl_position_24h, mfi_14), bb_position_50)), GT(rsi_21, IfPos(rsi_7, Sub(rsi_7, Sub(mfi_14, rsi_7)), rsi_21)))
#
# Fold 137  OOS: 2024-02-06 → 2024-02-20
#   Fitness: +35.6661  (Sharpe − 0.002 × 43 nodes)
#   Nodes: 43  Height: 8
#   Rule: Sub(IfPos(GT(Sub(IfPos(macd_hist_12_26, Or(GT(Sub(macd_hist_12_26, cmf_20), rsi_7), GT(rsi_7, mfi_14)), obv_z_72), IfPos(cmf_20, williams_r, cmf_20)), rsi_7), rsi_7, And(Or(GT(Sub(macd_hist_12_26, cmf_20), rsi_7), GT(rsi_7, mfi_14)), Not(GT(GT(macd_hist_12_26, GT(mfi_14, rsi_7)), rsi_21)))), GT(rsi_21, rsi_7))
#
# Fold 138  OOS: 2024-02-20 → 2024-03-05
#   Fitness: +35.2580  (Sharpe − 0.002 × 40 nodes)
#   Nodes: 40  Height: 8
#   Rule: Sub(GT(rsi_21, GT(mfi_14, rsi_7)), Or(GT(LT(rsi_7, GT(Or(GT(williams_r, LT(rsi_21, rsi_7)), GT(Not(williams_r), And(obv_z_72, rsi_7))), LT(macd_hist_12_26, IfPos(LT(williams_r, rsi_7), Sub(bb_position_50, bb_position_50), macd_hist_12_26)))), bb_squeeze_20), GT(Not(rsi_7), And(mfi_14, mfi_14))))
#
# Fold 139  OOS: 2024-03-05 → 2024-03-19
#   Fitness: +35.2106  (Sharpe − 0.002 × 31 nodes)
#   Nodes: 31  Height: 7
#   Rule: IfPos(LT(Not(Not(hl_position_24h)), bb_squeeze_20), stoch_k_21, Sub(LT(rsi_21, LT(rsi_21, rsi_7)), Not(IfPos(Or(GT(stoch_k_21, Sub(rsi_21, mfi_14)), bb_position_50), GT(rsi_7, mfi_14), And(Not(And(macd_hist_12_26, rsi_21)), macd_hist_12_26)))))
#
# Fold 140  OOS: 2024-03-19 → 2024-04-02
#   Fitness: +37.3371  (Sharpe − 0.002 × 32 nodes)
#   Nodes: 32  Height: 8
#   Rule: Sub(Sub(Sub(rsi_7, Sub(GT(Sub(Or(macd_hist_12_26, rsi_7), GT(LT(williams_r, stoch_k_21), Sub(macd_hist_12_26, mfi_14))), rsi_21), Not(And(Or(macd_hist_12_26, macd_hist_12_26), Sub(mfi_14, cmf_20))))), LT(rsi_7, mfi_14)), LT(rsi_7, rsi_21))
#
# Fold 141  OOS: 2024-04-02 → 2024-04-16
#   Fitness: +36.1518  (Sharpe − 0.002 × 30 nodes)
#   Nodes: 30  Height: 7
#   Rule: Sub(LT(Not(Sub(rsi_7, rsi_21)), rsi_7), LT(LT(mfi_14, rsi_7), And(hl_position_24h, Sub(LT(Not(GT(bb_squeeze_20, hl_position_24h)), Or(And(macd_hist_12_26, rsi_21), macd_hist_12_26)), Sub(mfi_14, Not(Sub(rsi_7, rsi_21)))))))
#
# Fold 142  OOS: 2024-04-16 → 2024-04-30
#   Fitness: +35.7587  (Sharpe − 0.002 × 17 nodes)
#   Nodes: 17  Height: 4
#   Rule: Sub(LT(rsi_21, rsi_7), LT(LT(mfi_14, LT(mfi_14, rsi_7)), Sub(LT(rsi_7, rsi_21), Sub(bb_squeeze_20, williams_r))))
#
# Fold 143  OOS: 2024-04-30 → 2024-05-14
#   Fitness: +37.6745  (Sharpe − 0.002 × 54 nodes)
#   Nodes: 54  Height: 6
#   Rule: Sub(LT(Or(LT(rsi_7, mfi_14), GT(And(LT(rsi_7, rsi_21), And(macd_hist_12_26, rsi_21)), rsi_7)), Or(williams_r, stoch_k_21)), IfPos(Or(And(rsi_7, rsi_7), LT(cmf_20, Or(LT(rsi_7, rsi_7), macd_hist_12_26))), IfPos(LT(rsi_7, rsi_21), And(rsi_7, GT(IfPos(stoch_k_21, williams_r, hl_position_24h), Sub(bb_squeeze_20, mfi_14))), Sub(williams_r, stoch_k_21)), GT(GT(vol_z_24h, rsi_7), GT(cmf_20, williams_r))))
#
# Fold 144  OOS: 2024-05-14 → 2024-05-28
#   Fitness: +36.8530  (Sharpe − 0.002 × 22 nodes)
#   Nodes: 22  Height: 8
#   Rule: Sub(GT(rsi_7, mfi_14), LT(rsi_7, GT(IfPos(stoch_k_21, rsi_21, bb_position_50), Sub(Sub(Sub(Sub(Sub(rsi_7, macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26))))
#
# Fold 145  OOS: 2024-05-28 → 2024-06-11
#   Fitness: +36.0587  (Sharpe − 0.002 × 9 nodes)
#   Nodes: 9  Height: 3
#   Rule: Sub(LT(mfi_14, LT(rsi_21, rsi_7)), LT(rsi_7, mfi_14))
#
# Fold 146  OOS: 2024-06-11 → 2024-06-25
#   Fitness: +38.2568  (Sharpe − 0.002 × 25 nodes)
#   Nodes: 25  Height: 6
#   Rule: Sub(Sub(hl_position_24h, williams_r), Sub(LT(Not(GT(rsi_21, rsi_7)), rsi_7), Or(Or(Not(LT(rsi_7, mfi_14)), Sub(Sub(hl_position_24h, mfi_14), mfi_14)), Sub(rsi_7, mfi_14))))
#
# Fold 147  OOS: 2024-06-25 → 2024-07-09
#   Fitness: +37.7251  (Sharpe − 0.002 × 63 nodes)
#   Nodes: 63  Height: 7
#   Rule: Sub(LT(IfPos(LT(rsi_21, rsi_7), Sub(Sub(Sub(macd_hist_12_26, williams_r), hl_position_24h), LT(Sub(stoch_k_21, mfi_14), Sub(cmf_20, cmf_20))), Not(mfi_14)), Not(And(stoch_k_21, rsi_7))), Or(Sub(GT(mfi_14, rsi_7), LT(GT(IfPos(hl_position_24h, stoch_k_21, obv_z_72), Not(hl_position_24h)), Sub(Not(stoch_k_21), Sub(macd_hist_12_26, bb_position_50)))), IfPos(LT(macd_hist_12_26, rsi_7), Sub(Sub(williams_r, LT(LT(williams_r, williams_r), rsi_7)), Sub(stoch_k_21, IfPos(bb_squeeze_20, rsi_21, rsi_21))), mfi_14)))
#
# Fold 148  OOS: 2024-07-09 → 2024-07-23
#   Fitness: +36.3696  (Sharpe − 0.002 × 22 nodes)
#   Nodes: 22  Height: 4
#   Rule: IfPos(Not(Not(GT(bb_squeeze_20, williams_r))), Sub(LT(mfi_14, rsi_7), LT(rsi_7, rsi_21)), Sub(LT(LT(rsi_7, rsi_21), rsi_7), LT(rsi_7, rsi_21)))
#
# Fold 149  OOS: 2024-07-23 → 2024-08-06
#   Fitness: +35.9016  (Sharpe − 0.002 × 9 nodes)
#   Nodes: 9  Height: 3
#   Rule: Sub(rsi_7, LT(LT(mfi_14, rsi_7), Sub(williams_r, cmf_20)))
#
# Fold 150  OOS: 2024-08-06 → 2024-08-20
#   Fitness: +38.0866  (Sharpe − 0.002 × 16 nodes)
#   Nodes: 16  Height: 3
#   Rule: Sub(IfPos(GT(rsi_7, rsi_21), Or(rsi_7, mfi_14), Sub(rsi_7, williams_r)), And(Sub(mfi_14, rsi_7), williams_r))
#
# Fold 151  OOS: 2024-08-20 → 2024-09-03
#   Fitness: +37.6742  (Sharpe − 0.002 × 21 nodes)
#   Nodes: 21  Height: 7
#   Rule: Sub(GT(rsi_7, rsi_21), Not(LT(IfPos(IfPos(Not(LT(bb_squeeze_20, vol_z_24h)), LT(cmf_20, bb_position_50), GT(stoch_k_21, bb_position_50)), mfi_14, rsi_21), rsi_7)))
#
# Fold 152  OOS: 2024-09-03 → 2024-09-17
#   Fitness: +41.5959  (Sharpe − 0.002 × 40 nodes)
#   Nodes: 40  Height: 8
#   Rule: Sub(Sub(Sub(And(And(rsi_7, stoch_k_21), GT(rsi_7, rsi_21)), LT(Sub(Sub(And(And(mfi_14, rsi_7), GT(rsi_7, williams_r)), LT(GT(rsi_7, mfi_14), stoch_k_21)), Sub(macd_hist_12_26, mfi_14)), IfPos(IfPos(Not(rsi_7), macd_hist_12_26, macd_hist_12_26), mfi_14, mfi_14))), Sub(macd_hist_12_26, rsi_7)), williams_r)
#
# Fold 153  OOS: 2024-09-17 → 2024-10-01
#   Fitness: +39.2216  (Sharpe − 0.002 × 16 nodes)
#   Nodes: 16  Height: 5
#   Rule: Sub(And(LT(mfi_14, rsi_7), GT(rsi_7, Sub(williams_r, IfPos(macd_hist_12_26, bb_position_50, rsi_7)))), LT(rsi_7, rsi_21))
#
# Fold 154  OOS: 2024-10-01 → 2024-10-15
#   Fitness: +39.6586  (Sharpe − 0.002 × 22 nodes)
#   Nodes: 22  Height: 6
#   Rule: Sub(LT(GT(mfi_14, rsi_7), GT(LT(rsi_21, rsi_7), macd_hist_12_26)), Sub(Or(IfPos(Not(LT(rsi_21, rsi_7)), williams_r, macd_hist_12_26), Not(hl_position_24h)), rsi_7))
#
# Fold 155  OOS: 2024-10-15 → 2024-10-29
#   Fitness: +39.2674  (Sharpe − 0.002 × 41 nodes)
#   Nodes: 41  Height: 8
#   Rule: Sub(Not(And(Or(macd_hist_12_26, And(And(mfi_14, rsi_7), Sub(rsi_21, rsi_7))), And(Or(LT(GT(GT(obv_z_72, rsi_7), GT(bb_squeeze_20, obv_z_72)), And(rsi_7, Not(obv_z_72))), And(And(mfi_14, rsi_7), Sub(rsi_21, rsi_7))), Sub(mfi_14, rsi_7)))), And(williams_r, Sub(rsi_21, rsi_7)))
#
# Fold 156  OOS: 2024-10-29 → 2024-11-12
#   Fitness: +38.4295  (Sharpe − 0.002 × 26 nodes)
#   Nodes: 26  Height: 5
#   Rule: Sub(LT(mfi_14, rsi_7), IfPos(GT(Not(LT(rsi_7, rsi_21)), rsi_7), LT(stoch_k_21, IfPos(LT(stoch_k_21, stoch_k_21), GT(stoch_k_21, rsi_7), Sub(mfi_14, hl_position_24h))), Or(rsi_21, rsi_21)))
#
# Fold 157  OOS: 2024-11-12 → 2024-11-26
#   Fitness: +39.8785  (Sharpe − 0.002 × 64 nodes)
#   Nodes: 64  Height: 8
#   Rule: Sub(rsi_7, Sub(And(Or(IfPos(Not(mfi_14), GT(rsi_21, williams_r), LT(rsi_7, mfi_14)), IfPos(GT(GT(Sub(vol_z_24h, rsi_7), IfPos(mfi_14, bb_position_50, cmf_20)), And(Or(macd_hist_12_26, bb_position_50), And(bb_squeeze_20, macd_hist_12_26))), IfPos(Sub(IfPos(stoch_k_21, hl_position_24h, williams_r), Sub(vol_z_24h, bb_position_50)), Not(vol_z_24h), GT(mfi_14, hl_position_24h)), LT(Not(And(hl_position_24h, macd_hist_12_26)), And(rsi_21, mfi_14)))), williams_r), Not(LT(rsi_7, IfPos(Not(LT(rsi_7, cmf_20)), rsi_21, williams_r)))))
#
# Fold 158  OOS: 2024-11-26 → 2024-12-10
#   Fitness: +40.1337  (Sharpe − 0.002 × 29 nodes)
#   Nodes: 29  Height: 8
#   Rule: Sub(GT(Sub(Sub(Sub(Sub(Sub(Sub(rsi_7, rsi_21), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), macd_hist_12_26), GT(Or(LT(hl_position_24h, mfi_14), macd_hist_12_26), GT(Sub(Sub(rsi_7, rsi_21), macd_hist_12_26), macd_hist_12_26)))
#
# Fold 159  OOS: 2024-12-10 → 2024-12-24
#   Fitness: +38.5109  (Sharpe − 0.002 × 7 nodes)
#   Nodes: 7  Height: 2
#   Rule: Sub(LT(mfi_14, rsi_7), GT(rsi_21, rsi_7))
#
# Fold 160  OOS: 2024-12-24 → 2025-01-07
#   Fitness: +41.3036  (Sharpe − 0.002 × 16 nodes)
#   Nodes: 16  Height: 4
#   Rule: Sub(GT(rsi_7, Sub(LT(rsi_7, mfi_14), Sub(rsi_7, williams_r))), Or(Not(rsi_7), Sub(rsi_21, rsi_7)))
#
# Fold 161  OOS: 2025-01-07 → 2025-01-21
#   Fitness: +38.2859  (Sharpe − 0.002 × 19 nodes)
#   Nodes: 19  Height: 6
#   Rule: Sub(rsi_7, Or(LT(mfi_14, mfi_14), And(Or(LT(rsi_7, mfi_14), And(macd_hist_12_26, LT(rsi_7, rsi_21))), LT(rsi_7, rsi_21))))
#
# Fold 162  OOS: 2025-01-21 → 2025-02-04
#   Fitness: +42.4569  (Sharpe − 0.002 × 61 nodes)
#   Nodes: 61  Height: 8
#   Rule: Sub(Not(Or(LT(mfi_14, cmf_20), Sub(rsi_21, rsi_7))), GT(And(LT(IfPos(williams_r, rsi_7, williams_r), mfi_14), Or(Not(Sub(rsi_21, bb_position_50)), Sub(IfPos(Or(And(stoch_k_21, cmf_20), mfi_14), Not(LT(rsi_21, cmf_20)), mfi_14), vol_z_24h))), Sub(Sub(IfPos(bb_squeeze_20, hl_position_24h, Not(Or(LT(mfi_14, cmf_20), Sub(rsi_21, rsi_7)))), LT(Not(Or(LT(mfi_14, cmf_20), Sub(rsi_21, rsi_7))), macd_hist_12_26)), Sub(rsi_21, stoch_k_21))))
#
# Fold 163  OOS: 2025-02-04 → 2025-02-18
#   Fitness: +38.3007  (Sharpe − 0.002 × 13 nodes)
#   Nodes: 13  Height: 4
#   Rule: Sub(And(Not(Sub(mfi_14, stoch_k_21)), Not(Sub(macd_hist_12_26, macd_hist_12_26))), LT(rsi_7, rsi_21))
#
# Fold 164  OOS: 2025-02-18 → 2025-03-04
#   Fitness: +39.4460  (Sharpe − 0.002 × 26 nodes)
#   Nodes: 26  Height: 5
#   Rule: IfPos(And(GT(And(GT(mfi_14, rsi_7), And(mfi_14, rsi_7)), macd_hist_12_26), mfi_14), Sub(GT(rsi_7, rsi_21), GT(And(GT(mfi_14, rsi_7), And(rsi_7, rsi_7)), bb_position_50)), rsi_7)
#
# Fold 165  OOS: 2025-03-04 → 2025-03-18
#   Fitness: +40.1298  (Sharpe − 0.002 × 63 nodes)
#   Nodes: 63  Height: 8
#   Rule: Sub(IfPos(And(LT(Not(bb_position_50), Or(mfi_14, cmf_20)), stoch_k_21), GT(rsi_7, rsi_21), rsi_7), IfPos(IfPos(Or(IfPos(GT(Or(GT(obv_z_72, vol_z_24h), Or(stoch_k_21, stoch_k_21)), Sub(LT(bb_position_50, bb_squeeze_20), Or(cmf_20, obv_z_72))), mfi_14, obv_z_72), IfPos(Or(hl_position_24h, Not(bb_position_50)), Not(bb_position_50), Not(vol_z_24h))), GT(IfPos(bb_position_50, williams_r, bb_position_50), IfPos(macd_hist_12_26, cmf_20, stoch_k_21)), Sub(Not(bb_position_50), macd_hist_12_26)), LT(mfi_14, GT(mfi_14, rsi_7)), williams_r))
#
# Fold 166  OOS: 2025-03-18 → 2025-04-01
#   Fitness: +39.9821  (Sharpe − 0.002 × 52 nodes)
#   Nodes: 52  Height: 8
#   Rule: Sub(And(Sub(rsi_7, mfi_14), Or(And(LT(Sub(Sub(IfPos(cmf_20, rsi_21, obv_z_72), Sub(rsi_21, williams_r)), obv_z_72), rsi_7), rsi_7), IfPos(IfPos(williams_r, GT(IfPos(cmf_20, rsi_21, obv_z_72), Not(LT(rsi_21, rsi_7))), Not(vol_z_24h)), Or(LT(macd_hist_12_26, mfi_14), Or(macd_hist_12_26, rsi_21)), LT(LT(stoch_k_21, mfi_14), Or(williams_r, mfi_14))))), Not(LT(rsi_21, rsi_7)))
#
# Fold 167  OOS: 2025-04-01 → 2025-04-15
#   Fitness: +41.9819  (Sharpe − 0.002 × 17 nodes)
#   Nodes: 17  Height: 4
#   Rule: IfPos(Not(mfi_14), rsi_7, Sub(And(Sub(rsi_7, mfi_14), mfi_14), Sub(GT(rsi_21, rsi_7), Sub(rsi_7, williams_r))))
#
# Fold 168  OOS: 2025-04-15 → 2025-04-29
#   Fitness: +38.3028  (Sharpe − 0.002 × 26 nodes)
#   Nodes: 26  Height: 6
#   Rule: IfPos(LT(rsi_21, rsi_7), LT(cmf_20, rsi_7), Sub(LT(rsi_21, rsi_7), Or(macd_hist_12_26, Or(And(rsi_7, GT(cmf_20, mfi_14)), Sub(And(rsi_21, hl_position_24h), Sub(obv_z_72, rsi_7))))))
#
# Fold 169  OOS: 2025-04-29 → 2025-05-13
#   Fitness: +39.1583  (Sharpe − 0.002 × 26 nodes)
#   Nodes: 26  Height: 5
#   Rule: IfPos(Or(macd_hist_12_26, LT(rsi_7, rsi_21)), Sub(Sub(rsi_7, LT(Sub(rsi_7, macd_hist_12_26), rsi_21)), LT(Sub(rsi_7, macd_hist_12_26), rsi_21)), Or(GT(cmf_20, stoch_k_21), Or(vol_z_24h, rsi_21)))
#
# Fold 170  OOS: 2025-05-13 → 2025-05-27
#   Fitness: +40.6674  (Sharpe − 0.002 × 33 nodes)
#   Nodes: 33  Height: 8
#   Rule: Sub(Not(LT(rsi_7, rsi_21)), And(Or(GT(macd_hist_12_26, And(GT(Not(LT(rsi_7, rsi_21)), rsi_7), Sub(hl_position_24h, mfi_14))), And(rsi_21, LT(rsi_7, Sub(williams_r, rsi_7)))), LT(rsi_7, Or(obv_z_72, LT(rsi_7, rsi_21)))))
#
# Fold 171  OOS: 2025-05-27 → 2025-06-10
#   Fitness: +38.9967  (Sharpe − 0.002 × 13 nodes)
#   Nodes: 13  Height: 4
#   Rule: Sub(GT(rsi_7, rsi_21), LT(GT(Sub(rsi_7, macd_hist_12_26), rsi_21), LT(rsi_7, mfi_14)))
#
# Fold 172  OOS: 2025-06-10 → 2025-06-24
#   Fitness: +40.2410  (Sharpe − 0.002 × 53 nodes)
#   Nodes: 53  Height: 8
#   Rule: Sub(And(And(Sub(obv_z_72, bb_squeeze_20), Sub(rsi_7, rsi_21)), IfPos(GT(Sub(And(hl_position_24h, macd_hist_12_26), And(hl_position_24h, obv_z_72)), GT(Not(rsi_21), LT(rsi_21, bb_squeeze_20))), Sub(vol_z_24h, hl_position_24h), LT(mfi_14, stoch_k_21))), Sub(And(mfi_14, LT(rsi_7, rsi_21)), And(And(rsi_21, stoch_k_21), LT(mfi_14, LT(Not(And(Sub(rsi_7, mfi_14), IfPos(cmf_20, cmf_20, bb_position_50))), rsi_7)))))
#
# Fold 173  OOS: 2025-06-24 → 2025-07-08
#   Fitness: +40.8273  (Sharpe − 0.002 × 24 nodes)
#   Nodes: 24  Height: 8
#   Rule: Sub(GT(rsi_7, mfi_14), Sub(Not(Or(GT(rsi_7, GT(rsi_21, Sub(Sub(stoch_k_21, williams_r), williams_r))), GT(williams_r, williams_r))), GT(hl_position_24h, GT(rsi_21, rsi_7))))
#
# Fold 174  OOS: 2025-07-08 → 2025-07-22
#   Fitness: +40.5286  (Sharpe − 0.002 × 22 nodes)
#   Nodes: 22  Height: 7
#   Rule: Sub(LT(rsi_21, rsi_7), GT(LT(Sub(Or(mfi_14, Sub(Or(vol_z_24h, rsi_7), mfi_14)), mfi_14), williams_r), IfPos(macd_hist_12_26, rsi_7, LT(rsi_21, rsi_7))))
#
# Fold 175  OOS: 2025-07-22 → 2025-08-05
#   Fitness: +40.6867  (Sharpe − 0.002 × 50 nodes)
#   Nodes: 50  Height: 8
#   Rule: IfPos(Sub(Or(mfi_14, rsi_21), LT(cmf_20, williams_r)), IfPos(IfPos(Not(macd_hist_12_26), cmf_20, bb_position_50), And(cmf_20, bb_squeeze_20), Not(Sub(rsi_7, rsi_21))), Sub(Sub(LT(Sub(macd_hist_12_26, Sub(Not(stoch_k_21), Not(stoch_k_21))), Sub(LT(Sub(Sub(williams_r, rsi_21), bb_position_50), GT(rsi_7, vol_z_24h)), GT(rsi_21, rsi_7))), GT(rsi_21, rsi_7)), GT(mfi_14, rsi_7)))
#
# Fold 176  OOS: 2025-08-05 → 2025-08-19
#   Fitness: +38.3905  (Sharpe − 0.002 × 50 nodes)
#   Nodes: 50  Height: 8
#   Rule: Sub(rsi_7, And(And(IfPos(Not(macd_hist_12_26), And(Sub(IfPos(LT(mfi_14, rsi_7), GT(williams_r, bb_squeeze_20), rsi_7), GT(GT(cmf_20, stoch_k_21), Not(obv_z_72))), mfi_14), stoch_k_21), Sub(rsi_21, rsi_7)), IfPos(Not(macd_hist_12_26), And(Sub(IfPos(LT(mfi_14, rsi_7), Not(obv_z_72), rsi_7), GT(GT(cmf_20, stoch_k_21), Not(obv_z_72))), mfi_14), Sub(stoch_k_21, cmf_20))))
#
# Fold 177  OOS: 2025-08-19 → 2025-09-02
#   Fitness: +38.7050  (Sharpe − 0.002 × 7 nodes)
#   Nodes: 7  Height: 2
#   Rule: Sub(GT(rsi_7, mfi_14), GT(rsi_21, rsi_7))
#
# Fold 178  OOS: 2025-09-02 → 2025-09-16
#   Fitness: +40.0905  (Sharpe − 0.002 × 23 nodes)
#   Nodes: 23  Height: 6
#   Rule: Sub(GT(GT(LT(Sub(Sub(vol_z_24h, vol_z_24h), hl_position_24h), Sub(hl_position_24h, mfi_14)), GT(mfi_14, rsi_7)), GT(mfi_14, rsi_7)), GT(rsi_21, GT(rsi_7, rsi_21)))
#
# Fold 179  OOS: 2025-09-16 → 2025-09-30
#   Fitness: +42.3910  (Sharpe − 0.002 × 15 nodes)
#   Nodes: 15  Height: 4
#   Rule: Sub(Not(GT(rsi_21, rsi_7)), Sub(IfPos(rsi_7, GT(mfi_14, rsi_7), rsi_21), Sub(rsi_7, williams_r)))
#
# Fold 180  OOS: 2025-09-30 → 2025-10-14
#   Fitness: +38.1103  (Sharpe − 0.002 × 10 nodes)
#   Nodes: 10  Height: 3
#   Rule: Sub(LT(Not(stoch_k_21), LT(mfi_14, rsi_7)), LT(rsi_7, rsi_21))
#
# Fold 181  OOS: 2025-10-14 → 2025-10-28
#   Fitness: +39.5829  (Sharpe − 0.002 × 17 nodes)
#   Nodes: 17  Height: 5
#   Rule: Sub(LT(rsi_21, rsi_7), Not(LT(GT(GT(williams_r, cmf_20), LT(mfi_14, rsi_7)), IfPos(vol_z_24h, hl_position_24h, bb_position_50))))
#
# Fold 182  OOS: 2025-10-28 → 2025-11-11
#   Fitness: +39.9197  (Sharpe − 0.002 × 23 nodes)
#   Nodes: 23  Height: 8
#   Rule: Sub(Not(And(And(And(Sub(mfi_14, rsi_7), Sub(LT(Sub(stoch_k_21, rsi_7), IfPos(hl_position_24h, williams_r, macd_hist_12_26)), rsi_7)), rsi_21), rsi_21)), GT(rsi_21, rsi_7))
#
# Fold 183  OOS: 2025-11-11 → 2025-11-25
#   Fitness: +38.1646  (Sharpe − 0.002 × 7 nodes)
#   Nodes: 7  Height: 2
#   Rule: Sub(GT(rsi_7, rsi_21), LT(rsi_7, mfi_14))
#
# Fold 184  OOS: 2025-11-25 → 2025-12-09
#   Fitness: +40.1118  (Sharpe − 0.002 × 31 nodes)
#   Nodes: 31  Height: 8
#   Rule: Sub(GT(Sub(stoch_k_21, IfPos(rsi_21, rsi_7, bb_position_50)), williams_r), Sub(And(LT(rsi_21, LT(williams_r, Sub(GT(GT(mfi_14, rsi_7), Sub(stoch_k_21, cmf_20)), Not(rsi_21)))), rsi_21), LT(rsi_21, LT(rsi_21, rsi_7))))
#
# Fold 185  OOS: 2025-12-09 → 2025-12-23
#   Fitness: +40.2343  (Sharpe − 0.002 × 36 nodes)
#   Nodes: 36  Height: 8
#   Rule: Sub(GT(rsi_7, GT(rsi_21, rsi_7)), GT(IfPos(GT(Not(macd_hist_12_26), And(LT(williams_r, obv_z_72), GT(rsi_21, rsi_7))), GT(GT(rsi_21, rsi_7), Or(GT(GT(stoch_k_21, mfi_14), Not(Sub(rsi_7, mfi_14))), GT(obv_z_72, williams_r))), mfi_14), rsi_7))
#
# Fold 186  OOS: 2025-12-23 → 2026-01-06
#   Fitness: +39.6796  (Sharpe − 0.002 × 32 nodes)
#   Nodes: 32  Height: 7
#   Rule: Sub(Or(GT(GT(rsi_7, williams_r), And(macd_hist_12_26, GT(rsi_21, LT(bb_squeeze_20, bb_squeeze_20)))), GT(Or(Sub(rsi_7, mfi_14), And(GT(Not(bb_squeeze_20), Sub(bb_squeeze_20, hl_position_24h)), rsi_21)), LT(rsi_7, rsi_21))), GT(rsi_21, rsi_7))
#
# Fold 187  OOS: 2026-01-06 → 2026-01-20
#   Fitness: +39.2428  (Sharpe − 0.002 × 31 nodes)
#   Nodes: 31  Height: 7
#   Rule: Sub(GT(GT(rsi_7, rsi_21), hl_position_24h), GT(IfPos(williams_r, IfPos(macd_hist_12_26, Sub(Or(hl_position_24h, obv_z_72), Sub(Sub(hl_position_24h, williams_r), williams_r)), LT(hl_position_24h, williams_r)), Or(rsi_21, Or(rsi_7, mfi_14))), GT(rsi_7, rsi_21)))
#
# Fold 188  OOS: 2026-01-20 → 2026-02-03
#   Fitness: +38.8886  (Sharpe − 0.002 × 19 nodes)
#   Nodes: 19  Height: 5
#   Rule: Sub(LT(rsi_21, rsi_7), GT(IfPos(Or(obv_z_72, LT(rsi_21, rsi_7)), GT(mfi_14, rsi_7), Or(rsi_7, Not(bb_position_50))), bb_position_50))
#
# Fold 189  OOS: 2026-02-03 → 2026-02-17
#   Fitness: +38.8665  (Sharpe − 0.002 × 30 nodes)
#   Nodes: 30  Height: 7
#   Rule: Sub(LT(GT(rsi_21, Sub(Sub(rsi_7, macd_hist_12_26), macd_hist_12_26)), Or(stoch_k_21, Sub(rsi_7, cmf_20))), Not(IfPos(rsi_7, GT(bb_position_50, Or(Not(bb_position_50), Sub(williams_r, GT(rsi_7, mfi_14)))), And(macd_hist_12_26, hl_position_24h))))
#
# Fold 190  OOS: 2026-02-17 → 2026-03-03
#   Fitness: +40.8067  (Sharpe − 0.002 × 49 nodes)
#   Nodes: 49  Height: 8
#   Rule: Sub(Sub(Or(GT(IfPos(IfPos(mfi_14, rsi_21, hl_position_24h), IfPos(williams_r, stoch_k_21, williams_r), IfPos(bb_position_50, rsi_21, williams_r)), mfi_14), Sub(Sub(rsi_7, mfi_14), LT(LT(rsi_21, rsi_7), williams_r))), LT(LT(rsi_21, rsi_7), williams_r)), And(macd_hist_12_26, And(bb_position_50, GT(Sub(GT(rsi_21, rsi_7), Sub(rsi_7, Or(And(hl_position_24h, rsi_7), williams_r))), rsi_7))))
#
# Fold 191  OOS: 2026-03-03 → 2026-03-17
#   Fitness: +38.8234  (Sharpe − 0.002 × 26 nodes)
#   Nodes: 26  Height: 7
#   Rule: Sub(IfPos(bb_position_50, LT(rsi_21, rsi_7), rsi_21), IfPos(Not(LT(Not(LT(Sub(stoch_k_21, rsi_21), Sub(cmf_20, hl_position_24h))), IfPos(williams_r, bb_position_50, bb_position_50))), LT(rsi_7, mfi_14), williams_r))
#
# Fold 192  OOS: 2026-03-17 → 2026-03-31
#   Fitness: +42.5341  (Sharpe − 0.002 × 32 nodes)
#   Nodes: 32  Height: 7
#   Rule: Sub(rsi_7, Sub(GT(Sub(IfPos(rsi_21, GT(GT(rsi_21, rsi_7), Not(hl_position_24h)), vol_z_24h), And(LT(williams_r, rsi_7), IfPos(obv_z_72, williams_r, macd_hist_12_26))), Sub(Sub(stoch_k_21, macd_hist_12_26), stoch_k_21)), Sub(stoch_k_21, LT(rsi_7, mfi_14))))
#
# Fold 193  OOS: 2026-03-31 → 2026-04-14
#   Fitness: +39.8879  (Sharpe − 0.002 × 29 nodes)
#   Nodes: 29  Height: 6
#   Rule: Sub(GT(GT(GT(IfPos(rsi_21, Sub(bb_position_50, williams_r), rsi_7), Not(LT(mfi_14, rsi_7))), macd_hist_12_26), Not(IfPos(vol_z_24h, LT(rsi_21, rsi_7), And(GT(rsi_7, rsi_21), bb_position_50)))), GT(rsi_21, rsi_7))
#
# Fold 194  OOS: 2026-04-14 → 2026-04-28
#   Fitness: +39.7590  (Sharpe − 0.002 × 28 nodes)
#   Nodes: 28  Height: 7
#   Rule: Sub(GT(GT(rsi_7, mfi_14), GT(Or(Sub(mfi_14, rsi_7), GT(mfi_14, stoch_k_21)), IfPos(cmf_20, stoch_k_21, GT(GT(GT(rsi_7, mfi_14), GT(rsi_21, rsi_7)), rsi_7)))), GT(rsi_21, rsi_7))
#
# Fold 195  OOS: 2026-04-28 → 2026-05-12
#   Fitness: +39.9422  (Sharpe − 0.002 × 39 nodes)
#   Nodes: 39  Height: 8
#   Rule: Sub(rsi_7, IfPos(IfPos(And(GT(IfPos(Not(bb_position_50), stoch_k_21, bb_position_50), rsi_21), Or(Not(cmf_20), rsi_21)), Or(GT(IfPos(bb_squeeze_20, stoch_k_21, macd_hist_12_26), rsi_7), bb_position_50), Or(macd_hist_12_26, And(GT(IfPos(Not(bb_position_50), macd_hist_12_26, rsi_7), rsi_21), rsi_7))), GT(rsi_21, rsi_7), williams_r))
#
# Fold 196  OOS: 2026-05-12 → 2026-05-16
#   Fitness: +38.9347  (Sharpe − 0.002 × 20 nodes)
#   Nodes: 20  Height: 5
#   Rule: Sub(GT(rsi_7, rsi_21), LT(IfPos(GT(stoch_k_21, mfi_14), LT(Not(rsi_7), Sub(rsi_7, mfi_14)), rsi_7), Not(GT(rsi_7, rsi_7))))
#
#
# All-folds summary  (196 folds):
#   n_nodes  — mean: 30.1   range: [5, 74]
#   height   — mean: 6.2  range: [2, 8]
#   fitness  — mean: +36.5568  best: +43.6893
#   unique rules: 192 / 196  (v1 had persistent Sub(rsi_7,rsi_21) dominance)

# %%
# ── PHASE 2: Backtest ─────────────────────────────────────────────────────────
print('='*60)
print('PHASE 2 — OOS BACKTEST')
print('='*60)

def _sharpe(eq):
    r = np.diff(np.log(np.maximum(eq, 1e-12)))
    return float(r.mean() / (r.std(ddof=1) + 1e-12) * np.sqrt(24 * 365))

def _maxdd(eq):
    pk = np.maximum.accumulate(eq)
    return float(((eq - pk) / (pk + 1e-12)).min())


def run_gp_backtest(
    actions, close_arr, high_arr, low_arr, atr_arr,
    with_fees=True, sl_mult=2.0, tp_mult=3.0,
    min_hold=4, max_hold=24, cooldown=2,
):
    MAKER_FEE  = 0.0000
    SPOT_TAKER = TAKER_FEE
    FUT_TAKER  = TAKER_FEE
    MIN_SL     = 0.010

    n = len(close_arr)
    eq = np.ones(n); cur = 1.0
    trades = []

    in_pos = False; direction = None
    entry_px = sl_px = tp_px = entry_fee = funding = 0.0
    pos_eq = 1.0; hold_cnt = cd_cnt = 0

    for i in range(n):
        lo = low_arr[i]; hi = high_arr[i]; px = close_arr[i]
        act = int(actions[i])

        if in_pos:
            hold_cnt += 1
            if direction == 'short': funding += FUNDING_H
            eq[i] = pos_eq * (px / entry_px if direction == 'long'
                              else 1 + (entry_px - px) / entry_px)
            exited = False; exit_px = 0.; reason = ''; exit_fee = 0.

            if hold_cnt >= min_hold:
                if direction == 'long':
                    if   lo <= sl_px:                exit_px=sl_px;  exited=True; reason='sl';    exit_fee=SPOT_TAKER if with_fees else 0.
                    elif hi >= tp_px:                exit_px=tp_px;  exited=True; reason='tp';    exit_fee=MAKER_FEE
                    elif hold_cnt >= max_hold or act in (0, -1):
                                                     exit_px=px;     exited=True; reason='close'; exit_fee=SPOT_TAKER if with_fees else 0.
                else:
                    if   hi >= sl_px:                exit_px=sl_px;  exited=True; reason='sl';    exit_fee=FUT_TAKER  if with_fees else 0.
                    elif lo <= tp_px:                exit_px=tp_px;  exited=True; reason='tp';    exit_fee=MAKER_FEE
                    elif hold_cnt >= max_hold or act in (0, 1):
                                                     exit_px=px;     exited=True; reason='close'; exit_fee=FUT_TAKER  if with_fees else 0.

            if exited:
                gross = ((exit_px-entry_px)/entry_px if direction=='long'
                         else (entry_px-exit_px)/entry_px)
                net = gross - (entry_fee+exit_fee if with_fees else 0.) + funding
                cur = pos_eq*(1.+net); eq[i] = cur
                trades.append({'direction': direction, 'reason': reason,
                               'gross': gross, 'net': net, 'hold': hold_cnt})
                in_pos = False; cd_cnt = cooldown; funding = 0.
        elif cd_cnt > 0:
            cd_cnt -= 1; eq[i] = cur
        elif act != 0 and i+1 < n:
            atr = max(float(atr_arr[i]) if not np.isnan(atr_arr[i]) else MIN_SL, MIN_SL)
            direction = 'long' if act == 1 else 'short'
            entry_px = px
            entry_fee = SPOT_TAKER if with_fees else 0.
            if direction == 'long':
                sl_px = px*(1 - sl_mult*atr); tp_px = px*(1 + tp_mult*atr)
            else:
                sl_px = px*(1 + sl_mult*atr); tp_px = px*(1 - tp_mult*atr)
            in_pos=True; pos_eq=cur; hold_cnt=0; funding=0.
            eq[i] = cur
        else:
            eq[i] = cur

    if in_pos:
        px = close_arr[-1]
        gross = ((px-entry_px)/entry_px if direction=='long'
                 else (entry_px-px)/entry_px)
        tf = SPOT_TAKER if direction=='long' else FUT_TAKER
        net = gross - (entry_fee+(tf if with_fees else 0.)) + funding
        cur=pos_eq*(1.+net); eq[-1]=cur

    return eq, trades


_acts  = gp_signals.values
_close = oos_df['close'].values
_high  = oos_df['high'].values
_low   = oos_df['low'].values
_atr   = oos_df['atr_14_pct'].values

eq_fees, tdf_fees_raw = run_gp_backtest(_acts, _close, _high, _low, _atr, with_fees=True)
eq_0fee, tdf_0fee_raw = run_gp_backtest(_acts, _close, _high, _low, _atr, with_fees=False)

def _tdf(raw): return pd.DataFrame(raw) if raw else pd.DataFrame(
    columns=['direction','reason','gross','net','hold'])

tdf_fees = _tdf(tdf_fees_raw)
tdf_0fee = _tdf(tdf_0fee_raw)

print(f'\n{"":22}  {"Trades":>7}  {"L/S":>9}  {"WinRate":>8}  {"Return":>8}  {"Sharpe":>7}  {"MaxDD":>7}')
print('─'*75)
for lbl, eq, tdf in [
    ('With fees (primary)', eq_fees, tdf_fees),
    ('Zero-fee (upper)',    eq_0fee, tdf_0fee),
]:
    wr  = (tdf['net']>0).mean()                 if len(tdf) else 0.
    n_l = int((tdf['direction']=='long').sum())  if len(tdf) else 0
    n_s = int((tdf['direction']=='short').sum()) if len(tdf) else 0
    print(f'{lbl:22}  {len(tdf):>7}  {n_l:>4}/{n_s:<4}  {wr:>8.1%}  '
          f'{eq[-1]-1:>+7.1%}  {_sharpe(eq):>7.3f}  {_maxdd(eq):>7.2%}')
# Out:
# ============================================================
# PHASE 2 — OOS BACKTEST
# ============================================================
#
#                          Trades        L/S   WinRate    Return   Sharpe    MaxDD
# ───────────────────────────────────────────────────────────────────────────
# With fees (primary)        2151  1147/1004     33.8%   -96.5%   -3.823  -96.78%
# Zero-fee (upper)           2151  1147/1004     39.4%   -71.1%   -1.444  -76.11%

# %%
# ── Equity / drawdown plot ────────────────────────────────────────────────────
oos_index = oos_df.index
_oos_end_px   = oos_df['close'].iloc[-1]
_oos_start_px = oos_df['close'].iloc[0]
bh_pct = np.linspace(0., (_oos_end_px / _oos_start_px - 1) * 100, len(oos_index))

fig = plot_equity_drawdown(
    oos_index, eq_fees, tdf_fees,
    bh_pct=bh_pct,
    label='GP v2  (DEAP \u00b7 M1Y \u00b7 Long+Short \u00b7 w/fees  \u00b7 boolean-gate pset)',
    color=PURPLE,
)
fig.suptitle(
    f'GP v2 \u2014 DEAP \u00b7 M1Y Walk-Forward \u00b7 Long+Short \u00b7 w/Fees  |  OOS {OOS_START.date()}\n'
    f'logic_only={LOGIC_ONLY}  step={STEP_SIZE}h(2wk)  \u03b1={PARSIMONY}  flat_threshold=\u00b1{FLAT_THRESHOLD}  '
    f'cx={CX_PROB}  mut={MUT_PROB}  pop={POP_SIZE}  gen={GENERATIONS}',
    fontsize=10, fontweight='bold',
)
save_fig(fig, ARTS_DIR / '01_equity_drawdown.png')
plt.show()

# %%
# ── Fee comparison plot ───────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax = axes[0]
ax.plot(oos_index, eq_fees, color=ACCENT, lw=1.5, label='With fees')
ax.plot(oos_index, eq_0fee, color=BLUE,   lw=1.0, ls='--', alpha=0.7, label='Zero fee')
ax.set_title('Equity curves'); ax.set_ylabel('Portfolio value'); ax.legend()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=30)

ax = axes[1]
fee_drag = (eq_0fee - eq_fees) / (eq_0fee + 1e-12) * 100
ax.fill_between(oos_index, 0, fee_drag, color=RED, alpha=0.4, label='Fee drag %')
ax.set_title('Cumulative fee drag'); ax.set_ylabel('Fee drag (%)')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=30); ax.legend()

fig.suptitle(f'Fee Impact \u2014 GP v2  |  OOS {OOS_START.date()}', fontweight='bold', fontsize=11)
fig.tight_layout()
save_fig(fig, ARTS_DIR / '02_fee_comparison.png')
plt.show()

# %%
# ── Monthly return analysis ───────────────────────────────────────────────────
eq_full_series = pd.Series(eq_fees, index=oos_index)
monthly_ret = eq_full_series.resample('ME').last().pct_change().dropna() * 100

print('Monthly stats (w/ fees, full OOS):')
print(f'  Positive months : {(monthly_ret>0).sum()} / {len(monthly_ret)}')
print(f'  Avg monthly ret : {monthly_ret.mean():+.2f}%')
print(f'  Best month      : {monthly_ret.max():+.2f}%  ({monthly_ret.idxmax().strftime("%b %Y")})')
print(f'  Worst month     : {monthly_ret.min():+.2f}%  ({monthly_ret.idxmin().strftime("%b %Y")})')

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

ax = axes[0]
colors_bar = [GREEN if r >= 0 else RED for r in monthly_ret]
ax.bar(monthly_ret.index, monthly_ret.values, color=colors_bar, width=20)
ax.axhline(0, color='black', lw=0.8)
ax.set_title(f'Monthly Returns \u2014 GP v2 (with fees)\n'
             f'Positive: {(monthly_ret>0).sum()}/{len(monthly_ret)} | Avg: {monthly_ret.mean():+.2f}%',
             fontweight='bold')
ax.set_ylabel('Return (%)')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=30)

ax = axes[1]
pivot_df = monthly_ret.to_frame('ret')
pivot_df['year']  = pivot_df.index.year
pivot_df['month'] = pivot_df.index.month
try:
    heat = pivot_df.pivot(index='year', columns='month', values='ret')
    heat.columns = [calendar.month_abbr[m] for m in heat.columns]
    sns.heatmap(heat, annot=True, fmt='.1f', center=0,
                cmap='RdYlGn', linewidths=0.5, ax=ax,
                cbar_kws={'label': 'Monthly Return (%)', 'shrink': 0.6},
                annot_kws={'size': 9})
    ax.set_title('Monthly Return Heatmap (%)', fontweight='bold')
except Exception as e:
    ax.text(0.5, 0.5, str(e), ha='center', va='center', transform=ax.transAxes)

fig.tight_layout()
save_fig(fig, ARTS_DIR / '03_monthly_returns.png')
plt.show()
# Out:
# Monthly stats (w/ fees, full OOS):
#   Positive months : 3 / 28
#   Avg monthly ret : -10.66%
#   Best month      : +7.13%  (Feb 2026)
#   Worst month     : -23.59%  (May 2025)

# %%
# ── Action distribution ───────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax = axes[0]
act_names = {-1: 'Short', 0: 'Flat', 1: 'Long'}
vc = gp_signals.value_counts().sort_index()
bar_cols = [ac for k in vc.index for ac in [(RED if k==-1 else (GREY if k==0 else GREEN))]]
ax.bar([act_names.get(k, str(k)) for k in vc.index], vc.values, color=bar_cols, alpha=0.82)
for i, (k, v) in enumerate(vc.items()):
    ax.text(i, v + 5, f'{v/len(gp_signals)*100:.1f}%', ha='center', fontsize=9, fontweight='bold')
ax.set_title('Action Distribution (OOS)\n(v1 had 24.9% Flat; target: >40%)', fontweight='bold')
ax.set_ylabel('Bar count')

ax = axes[1]
act_series = pd.Series(_acts, index=gp_signals.index)
roll_w = 720
for act_val, col, name in [(-1, RED, 'Short'), (0, GREY, 'Flat'), (1, GREEN, 'Long')]:
    frac = (act_series == act_val).rolling(roll_w).mean()
    ax.plot(frac.index, frac, color=col, lw=0.9, alpha=0.85, label=name)
ax.axhline(1/3, color='black', ls=':', lw=0.7, label='1/3 baseline')
ax.set_title('30-day Rolling Action Proportions', fontweight='bold')
ax.set_ylabel('Fraction'); ax.legend(ncol=2)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=30, ha='right')

fig.suptitle('GP v2 \u2014 Action Behaviour (OOS Period)', fontweight='bold')
fig.tight_layout()
save_fig(fig, ARTS_DIR / '04_action_distribution.png')
plt.show()

# %%
# ── Tree complexity across folds ──────────────────────────────────────────────
if agent.fold_winners:
    fold_nums   = [fw['fold']    for fw in agent.fold_winners]
    fold_nodes  = [fw['n_nodes'] for fw in agent.fold_winners]
    fold_height = [fw['height']  for fw in agent.fold_winners]
    fold_fitness= [fw['fitness'] for fw in agent.fold_winners]

    fig, axes = plt.subplots(1, 3, figsize=(16, 4))

    ax = axes[0]
    ax.bar(fold_nums, fold_nodes, color=BLUE, alpha=0.7)
    ax.axhline(np.mean(fold_nodes), color=ACCENT, lw=1.5, ls='--',
               label=f'Mean = {np.mean(fold_nodes):.1f} nodes')
    ax.set_xlabel('WFO fold'); ax.set_ylabel('n_nodes')
    ax.set_title('Tree complexity per fold\n(v0 mean was 13.1)', fontweight='bold')
    ax.legend(fontsize=8)

    ax = axes[1]
    ax.scatter(fold_nodes, fold_fitness, color=PURPLE, alpha=0.7, s=60)
    z = np.polyfit(fold_nodes, fold_fitness, 1)
    xr = np.linspace(min(fold_nodes), max(fold_nodes), 50)
    ax.plot(xr, np.polyval(z, xr), color=RED, lw=1.2, ls='--', label=f'Trend (slope={z[0]:+.3f})')
    ax.set_xlabel('n_nodes'); ax.set_ylabel('Fitness (penalised Sharpe)')
    ax.set_title('Fitness vs complexity\n(parsimony trade-off)', fontweight='bold')
    ax.legend(fontsize=8)

    ax = axes[2]
    all_rules = [fw['tree_str'] for fw in agent.fold_winners]
    from collections import Counter
    rule_counts = Counter(all_rules).most_common(8)
    labels = [r[:30]+'...' if len(r)>30 else r for r, _ in rule_counts]
    counts = [c for _, c in rule_counts]
    ax.barh(range(len(counts)), counts, color=GREEN, alpha=0.75)
    ax.set_yticks(range(len(labels))); ax.set_yticklabels(labels, fontsize=7)
    ax.set_xlabel('Fold count'); ax.set_title(f'Most common rules\n({len(set(all_rules))} unique / {len(all_rules)} total)', fontweight='bold')

    fig.suptitle('GP v1 \u2014 Evolved Tree Statistics', fontweight='bold')
    fig.tight_layout()
    save_fig(fig, ARTS_DIR / '05_tree_complexity.png')
    plt.show()

# %%
# ── v0 / v1 / v2 comparison ───────────────────────────────────────────────────
v0_results_path = REPO_DIR / 'artifacts' / '09_gp_omni_0fee_v0' / 'results.json'
v1_results_path = REPO_DIR / 'artifacts' / '09_gp_omni_0fee_v1' / 'results.json'

def _load_res(p):
    try:
        with open(p) as f: return json.load(f)
    except Exception: return None

v0_res = _load_res(v0_results_path)
v1_res = _load_res(v1_results_path)

def _fmt_res(res):
    if res is None: return dict(n_trades='N/A', flat_pct='N/A', win_rate='N/A',
                                total_ret='N/A', sharpe='N/A', maxdd='N/A',
                                zero_ret='N/A', zero_sh='N/A')
    bt = res.get('backtest_wfees', {}); bt0 = res.get('backtest_0fee', {})
    ad = res.get('action_dist', {})
    fp = ad.get('0', 0) / max(sum(ad.values()), 1) * 100 if ad else 0.
    return dict(
        n_trades=bt.get('n_trades', 0),
        flat_pct=f'{fp:.1f}%',
        win_rate=f'{bt.get("win_rate",0):.1%}',
        total_ret=f'{bt.get("total_ret",0):+.1%}',
        sharpe=f'{bt.get("sharpe",0):.3f}',
        maxdd=f'{bt.get("maxdd",0):.1%}',
        zero_ret=f'{bt0.get("total_ret",0):+.1%}',
        zero_sh=f'{bt0.get("sharpe",0):.3f}',
    )

r0 = _fmt_res(v0_res); r1 = _fmt_res(v1_res)
v2_flat = (gp_signals == 0).mean() * 100
v2_wr = (tdf_fees['net'] > 0).mean() if len(tdf_fees) else 0.
r2 = dict(
    n_trades=len(tdf_fees),
    flat_pct=f'{v2_flat:.1f}%',
    win_rate=f'{v2_wr:.1%}',
    total_ret=f'{eq_fees[-1]-1:+.1%}',
    sharpe=f'{_sharpe(eq_fees):.3f}',
    maxdd=f'{_maxdd(eq_fees):.1%}',
    zero_ret=f'{eq_0fee[-1]-1:+.1%}',
    zero_sh=f'{_sharpe(eq_0fee):.3f}',
)

print('\u250c' + '\u2500'*66 + '\u2510')
print(f'\u2502  {"METRIC":<28} {"GP v0":>10} {"GP v1":>10} {"GP v2":>10}  \u2502')
print('\u251c' + '\u2500'*66 + '\u2524')
for label, k in [
    ('Trades (OOS)',       'n_trades'),
    ('Flat % (OOS)',       'flat_pct'),
    ('Win Rate (w/fees)',  'win_rate'),
    ('Return (w/fees)',    'total_ret'),
    ('Sharpe (w/fees)',    'sharpe'),
    ('Max Drawdown',       'maxdd'),
]:
    print(f'\u2502  {label:<28} {str(r0[k]):>10} {str(r1[k]):>10} {str(r2[k]):>10}  \u2502')
print('\u251c' + '\u2500'*66 + '\u2524')
for label, k in [
    ('Return (0-fee)',  'zero_ret'),
    ('Sharpe (0-fee)', 'zero_sh'),
]:
    print(f'\u2502  {label:<28} {str(r0[k]):>10} {str(r1[k]):>10} {str(r2[k]):>10}  \u2502')
print('\u2514' + '\u2500'*66 + '\u2518')
# Out:
# ┌──────────────────────────────────────────────────────────────────┐
# │  METRIC                            GP v0      GP v1      GP v2  │
# ├──────────────────────────────────────────────────────────────────┤
# │  Trades (OOS)                          0          0       2151  │
# │  Flat % (OOS)                       0.0%      24.9%      30.2%  │
# │  Win Rate (w/fees)                  0.0%       0.0%      33.8%  │
# │  Return (w/fees)                   +0.0%      +0.0%     -96.5%  │
# │  Sharpe (w/fees)                   0.000      0.000     -3.823  │
# │  Max Drawdown                       0.0%       0.0%     -96.8%  │
# ├──────────────────────────────────────────────────────────────────┤
# │  Return (0-fee)                    +0.0%      +0.0%     -71.1%  │
# │  Sharpe (0-fee)                    0.000      0.000     -1.444  │
# └──────────────────────────────────────────────────────────────────┘

# %%
# ── Save results.json ─────────────────────────────────────────────────────────
def _bt_metrics(eq, tdf, label):
    wr = float((tdf['net']>0).mean()) if len(tdf) else 0.
    n_l = int((tdf['direction']=='long').sum())  if len(tdf) else 0
    n_s = int((tdf['direction']=='short').sum()) if len(tdf) else 0
    avg_hold = float(tdf['hold'].mean()) if len(tdf) else 0.
    return {
        'label':        label,
        'n_trades':     len(tdf),
        'n_long':       n_l,
        'n_short':      n_s,
        'win_rate':     round(wr, 4),
        'avg_hold_h':   round(avg_hold, 1),
        'total_return': round(float(eq[-1]-1), 4),
        'sharpe':       round(_sharpe(eq), 4),
        'max_drawdown': round(_maxdd(eq), 4),
    }

all_rules = [fw['tree_str'] for fw in agent.fold_winners] if agent.fold_winners else []

results = {
    'agent':     'GPTradingAgent v1',
    'notebook':  '09_gp_omni_0fee_v2',
    'created':   pd.Timestamp.now().isoformat(),
    'oos_start': str(OOS_START.date()),
    'oos_end':   str(oos_df.index[-1].date()),
    'oos_bars':  len(oos_df),
    'gp_config': {
        'population_size':  POP_SIZE,
        'generations':      GENERATIONS,
        'parsimony_alpha':  PARSIMONY,
        'flat_threshold':   FLAT_THRESHOLD,
        'cx_prob':          CX_PROB,
        'mut_prob':         MUT_PROB,
        'train_window_h':   TRAIN_WINDOW_H,
        'step_size':        STEP_SIZE,
        'n_features':       len(GP_FEATURES),
        'features':         GP_FEATURES,
        'unique_rules':     len(set(all_rules)),
        'total_folds':      len(agent.fold_winners),
        'afml_defences': [
            'Ch.2 feature stationarity — bounded oscillators only',
            'Ch.7 purged fitness — last 12 bars excluded each fold',
            'Ch.14 parsimony pressure — Fitness = Sharpe - α×n_nodes',
        ],
        'v1_fixes': [
            f'flat_threshold=±{FLAT_THRESHOLD} — replaces np.sign(), forces Flat state',
            f'parsimony_alpha 0.010 → {PARSIMONY} — allows richer trees',
            f'cx_prob 0.70 → {CX_PROB}, mut_prob 0.25 → {MUT_PROB} — more diversity',
            f'pop 300 → {POP_SIZE}, gen 30 → {GENERATIONS} — more search',
        ],
    },
    'backtest_with_fees': _bt_metrics(eq_fees, tdf_fees, 'with_fees'),
    'backtest_zero_fee':  _bt_metrics(eq_0fee, tdf_0fee, 'zero_fee'),
    'action_dist': {str(k): int(v) for k, v in gp_signals.value_counts().sort_index().items()},
    'fold_winners': [
        {
            'fold':      fw['fold'],
            'oos_start': str(fw['oos_start'].date()),
            'oos_end':   str(fw['oos_end'].date()),
            'n_nodes':   fw['n_nodes'],
            'height':    fw['height'],
            'fitness':   round(fw['fitness'], 4),
            'tree':      fw['tree_str'],
        }
        for fw in agent.fold_winners
        if fw['oos_start'] >= OOS_START
    ],
}

out_path = ARTS_DIR / 'results.json'
with open(out_path, 'w') as fh:
    json.dump(results, fh, indent=2)
print(f'Saved → {out_path}')

print(f"\n{'='*55}")
print(f"GP v1  OOS {results['oos_start']} → {results['oos_end']}")
print(f"{'='*55}")
m = results['backtest_with_fees']
print(f"Return : {m['total_return']:+.2%}")
print(f"Sharpe : {m['sharpe']:.3f}")
print(f"MaxDD  : {m['max_drawdown']:.2%}")
print(f"Trades : {m['n_trades']}  (L:{m['n_long']} S:{m['n_short']})")
print(f"WinRate: {m['win_rate']:.1%}")
flat_n = results['action_dist'].get('0', 0)
total_n = sum(results['action_dist'].values())
print(f"Flat % : {flat_n/total_n*100:.1f}%")
# Out:
# Saved → /Users/wojciech.neuman/Documents/hybrid-multi-agent-trading-system/artifacts/09_gp_omni_0fee_v2/results.json
#
# =======================================================
# GP v1  OOS 2024-01-01 → 2026-05-16
# =======================================================
# Return : -96.49%
# Sharpe : -3.823
# MaxDD  : -96.78%
# Trades : 2151  (L:1147 S:1004)
# WinRate: 33.8%
# Flat % : 30.2%

# %%
# ── Meta-learning integration preview ─────────────────────────────────────────
print('Meta-learning integration check')
print('\u2500'*45)

lgbm_cache = REPO_DIR / 'artifacts' / '02_lgbm_omni_0fee_v12' / 'lgbm_oos_signals.parquet'
drl_cache  = REPO_DIR / 'artifacts' / '07_drl_omni_0fee_v2'  / 'drl_oos_signals.parquet'

if lgbm_cache.exists():
    lgbm_signals = pd.read_parquet(lgbm_cache)['lgbm_p_up']
    master = pd.concat([lgbm_signals, gp_signals], axis=1).dropna()
    master.columns = ['lgbm_p_up', 'gp_action']
    print(f'Aligned LGBM+GP bars: {len(master):,}')
    corr = master['lgbm_p_up'].corr(master['gp_action'], method='spearman')
    print(f'Spearman \u03c1 (LGBM vs GP v1): {corr:.3f}')
    if abs(corr) < 0.3:
        print('\u2192 Low correlation \u2014 signal DIVERSITY confirmed (good for ensemble)')
    else:
        print('\u2192 Note: higher correlation reduces ensemble benefit')
else:
    print('LGBM signals not cached yet \u2014 run 02_lgbm_omni_0fee_v12 first.')

if drl_cache.exists():
    drl_signals_v2 = pd.read_parquet(drl_cache)['drl_action']
    master3 = pd.concat([gp_signals, drl_signals_v2], axis=1).dropna()
    master3.columns = ['gp_action', 'drl_action']
    corr_gp_drl = master3['gp_action'].corr(master3['drl_action'], method='spearman')
    print(f'\nSpearman \u03c1 (GP v1 vs DRL v2): {corr_gp_drl:.3f}')
    if abs(corr_gp_drl) < 0.3:
        print('\u2192 Low GP/DRL correlation \u2014 two independent failure modes, valuable for meta-labeling')
    else:
        print('\u2192 Note: GP and DRL signals are correlated')
else:
    print('\nDRL v2 signals not found \u2014 run 07_drl_omni_0fee_v2 first.')

print(f'\ngp_signals dtype: {gp_signals.dtype}, name: {gp_signals.name}')
print('Ready for 08_meta_learning_v0 assembly.')
# Out:
# Meta-learning integration check
# ─────────────────────────────────────────────
# LGBM signals not cached yet — run 02_lgbm_omni_0fee_v12 first.
#
# Spearman ρ (GP v1 vs DRL v2): -0.013
# → Low GP/DRL correlation — two independent failure modes, valuable for meta-labeling
#
# gp_signals dtype: int8, name: gp_action
# Ready for 08_meta_learning_v0 assembly.
